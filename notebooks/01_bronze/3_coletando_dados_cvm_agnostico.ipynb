# %%
import pandas as pd
import requests
import zipfile
import io
import os
import datetime
from sqlalchemy import create_engine, text, inspect
from urllib.parse import quote_plus
from dotenv import load_dotenv

# %%
# Carrega variáveis de ambiente
load_dotenv()
# Out:
# True

# %%
class CVMLakeBuilder:
    """
    Classe responsável pela orquestração do pipeline ETL de dados da CVM.
    Suporta ingestão de múltiplos tipos de documentos (FRE, DFP, ITR, CAD).
    """

    # Mapeamento de configurações por tipo de arquivo
    DATASET_CONFIG = {
        'FRE': {
            'base_url': 'https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/FRE/DADOS/',
            'file_prefix': 'fre_cia_aberta',
            'is_zip': True,
            'is_historical': True # Tem arquivos por ano (2010, 2011...)
        },
        'DFP': {
            'base_url': 'https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/',
            'file_prefix': 'dfp_cia_aberta',
            'is_zip': True,
            'is_historical': True
        },
        'ITR': {
            'base_url': 'https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/',
            'file_prefix': 'itr_cia_aberta',
            'is_zip': True,
            'is_historical': True
        },
        # CONFIGURAÇÃO DO CAD AJUSTADA
        'CAD': {
            'base_url': 'https://dados.cvm.gov.br/dados/CIA_ABERTA/CAD/DADOS/',
            'file_prefix': 'cad_cia_aberta', # Nome do arquivo sem extensão
            'is_zip': False,       # É um CSV direto
            'is_historical': False # É um arquivo único, não tem ano no nome
        }
    }

    def __init__(self, dataset_type, schema='layer_01_bronze'):
        self.dataset_type = dataset_type.upper()
        self.schema = schema
        
        if self.dataset_type not in self.DATASET_CONFIG:
            raise ValueError(f"Dataset '{dataset_type}' não configurado. Opções: {list(self.DATASET_CONFIG.keys())}")
            
        self.config = self.DATASET_CONFIG[self.dataset_type]
        self.log_table = f"{self.dataset_type.lower()}_raw_logs_by_timestamp"
        self.engine = self._create_db_engine()
        
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
        }

    def _create_db_engine(self):
        user = quote_plus(os.getenv('DB_USER', 'postgres'))
        password = quote_plus(os.getenv('DB_PASS', 'password'))
        host = os.getenv('DB_HOST', 'localhost')
        port = os.getenv('DB_PORT', '5432')
        dbname = os.getenv('DB_NAME', 'data_lake')
        
        connection_str = f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{dbname}"
        return create_engine(connection_str)

    def setup_database(self):
        create_log_query = f"""
        CREATE TABLE IF NOT EXISTS {self.schema}.{self.log_table} (
            log_id SERIAL PRIMARY KEY,
            data_execucao TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            nivel_log VARCHAR(50),
            ano_referencia INT,
            arquivo_origem VARCHAR(200),
            tabela_destino VARCHAR(200),
            mensagem TEXT,
            schema_drift_detectado BOOLEAN DEFAULT FALSE
        );
        """
        try:
            with self.engine.connect() as conn:
                conn.execute(text(f"CREATE SCHEMA IF NOT EXISTS {self.schema};"))
                conn.execute(text(create_log_query))
                conn.commit()
            print(f"✅ Setup: Tabela de logs '{self.log_table}' verificada.")
        except Exception as e:
            print(f"❌ Erro no setup do banco: {e}")

    def _log(self, nivel, ano, arquivo, tabela, msg, drift=False):
        query = text(f"""
            INSERT INTO {self.schema}.{self.log_table} 
            (nivel_log, ano_referencia, arquivo_origem, tabela_destino, mensagem, schema_drift_detectado, data_execucao)
            VALUES (:niv, :ano, :arq, :tab, :msg, :drift, NOW())
        """)
        
        icon = "🟢" if nivel == 'SUCCESS' else "🟡" if nivel == 'WARNING' else "🔴"
        # Ajuste visual para quando não tem ano (CAD)
        ano_str = str(ano) if ano > 0 else "ATUAL"
        print(f"{icon} [{self.dataset_type}][{ano_str}][{nivel}] {msg}")

        try:
            with self.engine.connect() as conn:
                conn.execute(query, {'niv': nivel, 'ano': ano, 'arq': arquivo, 'tab': tabela, 'msg': msg, 'drift': drift})
                conn.commit()
        except Exception as e:
            print(f"Erro fatal ao tentar logar no banco: {e}")

    def _check_already_processed(self, filename):
        # Para arquivos únicos como CAD, talvez queiramos processar sempre (sobrescrever/append)
        # ou verificar se processamos hoje. Por enquanto, mantemos a lógica padrão.
        query = text(f"""
            SELECT 1 FROM {self.schema}.{self.log_table}
            WHERE arquivo_origem = :arq 
              AND nivel_log = 'SUCCESS'
              AND mensagem LIKE 'Processamento do arquivo finalizado%'
              -- Se for CAD, podemos querer verificar se já rodou HOJE, mas deixarei simples por ora
        """)
        with self.engine.connect() as conn:
            return conn.execute(query, {'arq': filename}).fetchone() is not None

    def _check_schema_drift(self, table_name, df_new):
        inspector = inspect(self.engine)
        if not inspector.has_table(table_name, schema=self.schema):
            return False, "Nova Tabela"

        cols_db = {col['name'] for col in inspector.get_columns(table_name, schema=self.schema)}
        cols_new = set(df_new.columns)
        new_cols = cols_new - cols_db
        
        if new_cols:
            return True, f"Drift: Novas colunas detectadas: {new_cols}"
        return False, "Schema OK"

    def _process_csv(self, csv_name, file_content, year, origin_file_name):
        """
        Lê o CSV (do zip ou direto), normaliza e salva.
        """
        try:
            # 1. Definição do nome da tabela
            # Limpeza do nome: remove extensão e ano se houver
            clean_name = csv_name.lower().replace('.csv', '')
            if year > 0:
                clean_name = clean_name.replace(f'_{year}', '')
            
            prefix = self.config['file_prefix'].split('_')[0] 
            
            if not clean_name.startswith(prefix):
                table_name = f"{prefix}_{clean_name}"
            else:
                table_name = clean_name
            
            # 2. Leitura do CSV
            df = pd.read_csv(
                file_content, 
                sep=';', 
                encoding='windows-1252', 
                on_bad_lines='skip', 
                low_memory=False
            )
            
            # 3. Metadados
            df['metadata_data_carga'] = datetime.datetime.now()
            df['metadata_arquivo_origem'] = origin_file_name
            
            df = df.astype(str)

            # 4. Drift e Carga
            is_drift, msg_drift = self._check_schema_drift(table_name, df)
            if is_drift:
                self._log('WARNING', year, csv_name, table_name, msg_drift, drift=True)

            df.to_sql(
                table_name,
                self.engine,
                schema=self.schema,
                if_exists='append',
                index=False,
                method='multi',
                chunksize=1000
            )
            
            self._log('INFO', year, csv_name, table_name, f"Carga OK: {len(df)} linhas.")

        except Exception as e:
            self._log('ERROR', year, csv_name, table_name if 'table_name' in locals() else 'unknown', f"Erro processando CSV: {str(e)}")

    def run_pipeline(self, start_year=2010, end_year=None):
        """
        Executa o pipeline. Se for histórico, usa o loop de anos. Se não (CAD), baixa o arquivo único.
        """
        if end_year is None:
            end_year = datetime.datetime.now().year

        self.setup_database()
        
        # Lógica para definir quais arquivos baixar
        files_to_process = []

        if self.config['is_historical']:
            print(f"\n🚀 Iniciando Pipeline Histórico ({start_year}-{end_year})...\n")
            for year in range(start_year, end_year + 1):
                file_name = f"{self.config['file_prefix']}_{year}.zip"
                url = f"{self.config['base_url']}{file_name}"
                files_to_process.append({'year': year, 'url': url, 'filename': file_name})
        else:
            # Lógica para arquivo único (CAD)
            print(f"\n🚀 Iniciando Pipeline Arquivo Único (Snapshot Atual)...\n")
            ext = ".zip" if self.config['is_zip'] else ".csv"
            file_name = f"{self.config['file_prefix']}{ext}"
            url = f"{self.config['base_url']}{file_name}"
            # Usamos ano=0 ou ano atual para representar o snapshot
            files_to_process.append({'year': end_year, 'url': url, 'filename': file_name})

        # Loop de processamento unificado
        for item in files_to_process:
            year = item['year']
            file_name = item['filename']
            url = item['url']

            # Idempotência simples (pode ser desativada para CAD se quiser sempre atualizar)
            if self._check_already_processed(file_name):
                print(f"⏭️  {file_name} já processado. Pulando.")
                continue

            try:
                self._log('INFO', year, file_name, '-', 'Baixando arquivo...')
                response = requests.get(url, headers=self.headers, timeout=120)
                
                if response.status_code != 200:
                    self._log('ERROR', year, file_name, '-', f"HTTP Erro: {response.status_code} - URL: {url}")
                    continue

                # DECISÃO: É ZIP ou CSV Direto?
                if self.config['is_zip']:
                    # Processamento ZIP (FRE, DFP, ITR)
                    try:
                        with zipfile.ZipFile(io.BytesIO(response.content)) as z:
                            csv_files = [f for f in z.namelist() if f.endswith('.csv')]
                            if not csv_files:
                                self._log('WARNING', year, file_name, '-', 'Zip vazio.')
                                continue
                            for csv in csv_files:
                                with z.open(csv) as f:
                                    self._process_csv(csv, f, year, file_name)
                    except zipfile.BadZipFile:
                        self._log('ERROR', year, file_name, '-', 'Arquivo corrompido ou não é um ZIP válido.')
                        continue
                else:
                    # Processamento CSV Direto (CAD)
                    # Envolvemos o conteúdo num BytesIO para simular um arquivo aberto
                    file_buffer = io.BytesIO(response.content)
                    self._process_csv(file_name, file_buffer, year, file_name)

                self._log('SUCCESS', year, file_name, 'TODAS', 'Processamento do arquivo finalizado.')

            except Exception as e:
                self._log('FATAL', year, file_name, '-', f"Erro crítico: {str(e)}")

# %%
# ==============================================================================
# EXECUTANDO O CÓDIGO
# ==============================================================================

if __name__ == "__main__":
    # EXEMPLO DE USO:
    # Basta trocar o tipo abaixo para 'DFP', 'ITR', 'FRE' ou 'CAD'
    
    TIPO_ARQUIVO = 'CAD' 
    
    pipeline = CVMLakeBuilder(dataset_type=TIPO_ARQUIVO)
    
    # Roda para os últimos 3 anos, por exemplo
    ano_atual = datetime.datetime.now().year
    pipeline.run_pipeline(start_year=2010, end_year=ano_atual)
# Out:
# ✅ Setup: Tabela de logs 'cad_raw_logs_by_timestamp' verificada.
#
# 🚀 Iniciando Pipeline Arquivo Único (Snapshot Atual)...
#
# ⏭️  cad_cia_aberta.csv já processado. Pulando.

# %%
# ==============================================================================
# EXECUTANDO O CÓDIGO
# ==============================================================================

if __name__ == "__main__":
    # EXEMPLO DE USO:
    # Basta trocar o tipo abaixo para 'DFP', 'ITR', 'FRE' ou 'CAD'
    
    TIPO_ARQUIVO = 'CAD' 
    
    pipeline = CVMLakeBuilder(dataset_type=TIPO_ARQUIVO)
    
    # Roda para os últimos 3 anos, por exemplo
    ano_atual = datetime.datetime.now().year
    pipeline.run_pipeline(start_year=2010, end_year=ano_atual)
# Out:
# ✅ Setup: Tabela de logs 'cad_raw_logs_by_timestamp' verificada.
#
# 🚀 Iniciando Pipeline Arquivo Único (Snapshot Atual)...
#
# ⏭️  cad_cia_aberta.csv já processado. Pulando.

# %%
# ==============================================================================
# EXECUTANDO O CÓDIGO
# ==============================================================================

if __name__ == "__main__":
    # EXEMPLO DE USO:
    # Basta trocar o tipo abaixo para 'DFP', 'ITR', 'FRE' ou 'CAD'
    
    TIPO_ARQUIVO = 'ITR' 
    
    pipeline = CVMLakeBuilder(dataset_type=TIPO_ARQUIVO)
    
    # Roda para os últimos 3 anos, por exemplo
    ano_atual = datetime.datetime.now().year
    pipeline.run_pipeline(start_year=2010, end_year=ano_atual)
# Out:
# ✅ Setup: Tabela de logs 'itr_raw_logs_by_timestamp' verificada.
#
# 🚀 Iniciando Pipeline Histórico (2010-2026)...
#
# 🔴 [ITR][2010][INFO] Baixando arquivo...
# 🔴 [ITR][2010][ERROR] HTTP Erro: 404 - URL: https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2010.zip
# ⏭️  itr_cia_aberta_2011.zip já processado. Pulando.
# ⏭️  itr_cia_aberta_2012.zip já processado. Pulando.
# ⏭️  itr_cia_aberta_2013.zip já processado. Pulando.
# ⏭️  itr_cia_aberta_2014.zip já processado. Pulando.
# 🔴 [ITR][2015][INFO] Baixando arquivo...
# 🔴 [ITR][2015][INFO] Carga OK: 2155 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 128798 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 249281 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 216672 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 402595 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 1036 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 1558 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 83068 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 127510 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 448944 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 620991 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 21305 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 24689 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 118866 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 205613 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 82518 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 154036 linhas.
# 🔴 [ITR][2015][INFO] Carga OK: 4661 linhas.
# 🟢 [ITR][2015][SUCCESS] Processamento do arquivo finalizado.
# 🔴 [ITR][2016][INFO] Baixando arquivo...
# 🔴 [ITR][2016][INFO] Carga OK: 2110 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 126491 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 242607 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 213179 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 392173 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 912 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 1240 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 82632 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 126680 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 440592 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 602754 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 21098 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 24487 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 114788 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 199138 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 80974 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 149404 linhas.
# 🔴 [ITR][2016][INFO] Carga OK: 4636 linhas.
# 🟢 [ITR][2016][SUCCESS] Processamento do arquivo finalizado.
# 🔴 [ITR][2017][INFO] Baixando arquivo...
# 🔴 [ITR][2017][INFO] Carga OK: 2146 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 128978 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 244681 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 217592 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 394304 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 956 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 1620 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 85008 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 129257 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 448064 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 601716 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 21590 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 24779 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 116638 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 199160 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 82626 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 149684 linhas.
# 🔴 [ITR][2017][INFO] Carga OK: 4966 linhas.
# 🟢 [ITR][2017][SUCCESS] Processamento do arquivo finalizado.
# 🔴 [ITR][2018][INFO] Baixando arquivo...
# 🔴 [ITR][2018][INFO] Carga OK: 2113 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 125196 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 237741 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 214792 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 394692 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 998 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 1620 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 85546 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 132883 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 383720 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 518522 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 21844 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 25142 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 115180 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 200182 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 81696 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 149976 linhas.
# 🔴 [ITR][2018][INFO] Carga OK: 6658 linhas.
# 🟢 [ITR][2018][SUCCESS] Processamento do arquivo finalizado.
# 🔴 [ITR][2019][INFO] Baixando arquivo...
# 🔴 [ITR][2019][INFO] Carga OK: 2106 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 126068 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 232632 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 217079 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 389911 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 919 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 1572 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 86363 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 133055 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 451264 linhas.
# 🔴 [ITR][2019][ERROR] Erro processando CSV: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)
# 🔴 [ITR][2019][INFO] Carga OK: 21647 linhas.
# 🔴 [ITR][2019][INFO] Carga OK: 24853 linhas.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 15
#      13 # Roda para os últimos 3 anos, por exemplo
#      14 ano_atual = datetime.datetime.now().year
# ---> 15 pipeline.run_pipeline(start_year=2010, end_year=ano_atual)
#
# Cell In[13], line 238, in CVMLakeBuilder.run_pipeline(self, start_year, end_year)
#     236         for csv in csv_files:
#     237             with z.open(csv) as f:
# --> 238                 self._process_csv(csv, f, year, file_name)
#     239 except zipfile.BadZipFile:
#     240     self._log('ERROR', year, file_name, '-', 'Arquivo corrompido ou não é um ZIP válido.')
#
# Cell In[13], line 166, in CVMLakeBuilder._process_csv(self, csv_name, file_content, year, origin_file_name)
#     163     if is_drift:
#     164         self._log('WARNING', year, csv_name, table_name, msg_drift, drift=True)
# --> 166     df.to_sql(
#     167         table_name,
#     168         self.engine,
#     169         schema=self.schema,
#     170         if_exists='append',
#     171         index=False,
#     172         method='multi',
#     173         chunksize=1000
#     174     )
#     176     self._log('INFO', year, csv_name, table_name, f"Carga OK: {len(df)} linhas.")
#     178 except Exception as e:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:3109, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2911 """
#    2912 Write records stored in a DataFrame to a SQL database.
#    2913
#    (...)   3105 [(1,), (None,), (2,)]
#    3106 """  # noqa: E501
#    3107 from pandas.io import sql
# -> 3109 return sql.to_sql(
#    3110     self,
#    3111     name,
#    3112     con,
#    3113     schema=schema,
#    3114     if_exists=if_exists,
#    3115     index=index,
#    3116     index_label=index_label,
#    3117     chunksize=chunksize,
#    3118     dtype=dtype,
#    3119     method=method,
#    3120 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:2030, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2018 sql_engine = get_engine(engine)
#    2020 table = self.prep_table(
#    2021     frame=frame,
#    2022     name=name,
#    (...)   2027     dtype=dtype,
#    2028 )
# -> 2030 total_inserted = sql_engine.insert_records(
#    2031     table=table,
#    2032     con=self.con,
#    2033     frame=frame,
#    2034     name=name,
#    2035     index=index,
#    2036     schema=schema,
#    2037     chunksize=chunksize,
#    2038     method=method,
#    2039     **engine_kwargs,
#    2040 )
#    2042 self.check_case_sensitive(name=name, schema=schema)
#    2043 return total_inserted
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:1570, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1567 from sqlalchemy import exc
#    1569 try:
# -> 1570     return table.insert(chunksize=chunksize, method=method)
#    1571 except exc.StatementError as err:
#    1572     # GH34431
#    1573     # https://stackoverflow.com/a/67358288/6067848
#    1574     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1575     )|inf can not be used with MySQL"""
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:1121, in SQLTable.insert(self, chunksize, method)
#    1118     break
#    1120 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1121 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1122 # GH 46891
#    1123 if num_inserted is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:1029, in SQLTable._execute_insert_multi(self, conn, keys, data_iter)
#    1027 data = [dict(zip(keys, row)) for row in data_iter]
#    1028 stmt = insert(self.table).values(data)
# -> 1029 result = conn.execute(stmt)
#    1030 return result.rowcount
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525     if TYPE_CHECKING:
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#     531     raise exc.ObjectNotExecutableError(self)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:1633, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1625 schema_translate_map = execution_options.get(
#    1626     "schema_translate_map", None
#    1627 )
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
# -> 1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    1636     column_keys=keys,
#    1637     for_executemany=for_executemany,
#    1638     schema_translate_map=schema_translate_map,
#    1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
#    1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    (...)   1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\elements.py:729, in ClauseElement._compile_w_cache(self, dialect, compiled_cache, column_keys, for_executemany, schema_translate_map, **kw)
#     727 else:
#     728     extracted_params = None
# --> 729     compiled_sql = self._compiler(
#     730         dialect,
#     731         cache_key=elem_cache_key,
#     732         column_keys=column_keys,
#     733         for_executemany=for_executemany,
#     734         schema_translate_map=schema_translate_map,
#     735         **kw,
#     736     )
#     738     if not dialect._supports_statement_cache:
#     739         cache_hit = dialect.NO_DIALECT_SUPPORT
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\elements.py:324, in CompilerElement._compiler(self, dialect, **kw)
#     322 if TYPE_CHECKING:
#     323     assert isinstance(self, ClauseElement)
# --> 324 return dialect.statement_compiler(dialect, self, **kw)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\compiler.py:1447, in SQLCompiler.__init__(self, dialect, statement, cache_key, column_keys, for_executemany, linting, _supporting_against, **kwargs)
#    1444 self.truncated_names: Dict[Tuple[str, str], str] = {}
#    1445 self._truncated_counters: Dict[str, int] = {}
# -> 1447 Compiled.__init__(self, dialect, statement, **kwargs)
#    1449 if self.isinsert or self.isupdate or self.isdelete:
#    1450     if TYPE_CHECKING:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\compiler.py:887, in Compiled.__init__(self, dialect, statement, schema_translate_map, render_schema_translate, compile_kwargs)
#     885         assert isinstance(statement, Executable)
#     886     self.execution_options = statement._execution_options
# --> 887 self.string = self.process(self.statement, **compile_kwargs)
#     889 if render_schema_translate:
#     890     assert schema_translate_map is not None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\compiler.py:933, in Compiled.process(self, obj, **kwargs)
#     932 def process(self, obj: Visitable, **kwargs: Any) -> str:
# --> 933     return obj._compiler_dispatch(self, **kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\visitors.py:138, in Visitable._generate_compiler_dispatch.<locals>._compiler_dispatch(self, visitor, **kw)
#     136     return visitor.visit_unsupported_compilation(self, err, **kw)  # type: ignore  # noqa: E501
#     137 else:
# --> 138     return meth(self, **kw)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\compiler.py:5897, in SQLCompiler.visit_insert(self, insert_stmt, visited_bindparam, visiting_cte, **kw)
#    5890 if self.positional and visiting_cte is None:
#    5891     # if we are inside a CTE, don't count parameters
#    5892     # here since they wont be for insertmanyvalues. keep
#    5893     # visited_bindparam at None so no counting happens.
#    5894     # see #9173
#    5895     visited_bindparam = []
# -> 5897 crud_params_struct = crud._get_crud_params(
#    5898     self,
#    5899     insert_stmt,
#    5900     compile_state,
#    5901     toplevel,
#    5902     visited_bindparam=visited_bindparam,
#    5903     **kw,
#    5904 )
#    5906 if self.positional and visited_bindparam is not None:
#    5907     counted_bindparam = len(visited_bindparam)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\crud.py:394, in _get_crud_params(compiler, stmt, compile_state, toplevel, **kw)
#     388 if (
#     389     _compile_state_isinsert(compile_state)
#     390     and compile_state._has_multi_parameters
#     391 ):
#     392     # is a multiparams, is not an insert from a select
#     393     assert not stmt._select_names
# --> 394     multi_extended_values = _extend_values_for_multiparams(
#     395         compiler,
#     396         stmt,
#     397         compile_state,
#     398         cast(
#     399             "Sequence[_CrudParamElementStr]",
#     400             values,
#     401         ),
#     402         cast("Callable[..., str]", _column_as_key),
#     403         kw,
#     404     )
#     405     return _CrudParams(values, multi_extended_values)
#     406 elif (
#     407     not values
#     408     and compiler.for_executemany
#    (...)    413     # into an in-place multi values.  This supports
#     414     # insert_executemany_returning mode :)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\crud.py:1524, in _extend_values_for_multiparams(compiler, stmt, compile_state, initial_values, _column_as_key, kw)
#    1521 key = col.key
#    1523 if coercions._is_literal(row[key]):
# -> 1524     new_param = _create_bind_param(
#    1525         compiler,
#    1526         col,
#    1527         row[key],
#    1528         name=("%s_m%d" % (col.key, i + 1)),
#    1529         force_anonymous=has_visiting_cte,
#    1530         **kw,
#    1531     )
#    1532 else:
#    1533     new_param = compiler.process(row[key].self_group(), **kw)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\crud.py:476, in _create_bind_param(compiler, col, value, process, required, name, force_anonymous, **kw)
#     474 bindparam._is_crud = True
#     475 if process:
# --> 476     return bindparam._compiler_dispatch(compiler, **kw)
#     477 else:
#     478     return bindparam
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\visitors.py:138, in Visitable._generate_compiler_dispatch.<locals>._compiler_dispatch(self, visitor, **kw)
#     136     return visitor.visit_unsupported_compilation(self, err, **kw)  # type: ignore  # noqa: E501
#     137 else:
# --> 138     return meth(self, **kw)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\compiler.py:3681, in SQLCompiler.visit_bindparam(self, bindparam, within_columns_clause, literal_binds, skip_bind_expression, literal_execute, render_postcompile, **kwargs)
#    3669 def visit_bindparam(
#    3670     self,
#    3671     bindparam,
#    (...)   3677     **kwargs,
#    3678 ):
#    3680     if not skip_bind_expression:
# -> 3681         impl = bindparam.type.dialect_impl(self.dialect)
#    3682         if impl._has_bind_expression:
#    3683             bind_expression = impl.bind_expression(bindparam)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\type_api.py:875, in TypeEngine.dialect_impl(self, dialect)
#     864         raise NotImplementedError(
#     865             "Default TypeEngine.as_generic() "
#     866             "heuristic method was unsuccessful for {}. A custom "
#    (...)    870             )
#     871         )
#     873     return util.constructor_copy(self, self._generic_type_affinity)
# --> 875 def dialect_impl(self, dialect: Dialect) -> TypeEngine[_T]:
#     876     """Return a dialect-specific implementation for this
#     877     :class:`.TypeEngine`.
#     878
#     879     """
#     880     try:
#
# KeyboardInterrupt:
